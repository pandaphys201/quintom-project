# %%
from compute_dic import compute_dic
from pathlib import Path
import sys

sys.path.append('/home/theppawan/cosmo-research/quintom-project/likelihood')

# %%
chain_dir = Path(r'/home/theppawan/cosmo-research/quintom-project/chains')
compute_dic(str(chain_dir / 'quintom/DESI+CMB+SNIa/quintom_DESI+CMB+SNIa'), burnin_fraction=0.3)
# Out:
# Loading chains for prefix: /home/theppawan/cosmo-research/quintom-project/chains/quintom/DESI+CMB+SNIa/quintom_DESI+CMB+SNIa
# Loading Cobaya model from: /home/theppawan/cosmo-research/quintom-project/chains/quintom/DESI+CMB+SNIa/quintom_DESI+CMB+SNIa.updated.yaml
# Dynamically summing the following chi2 columns: ['chi2__bao.desi_2024_bao_all', 'chi2__cmb_distance_prior.CMB_Distance_Prior_wcdm', 'chi2__sn.pantheonplus']
# Evaluated Mean Parameters: {'H0': 66.18730762706458, 'omega_b': 0.022419198375223718, 'omega_cdm': 0.11339554561954505, 'lambda_qtm': 0.5307377109120976, 'delta_qtm': 0.0031112827048574965, 'Mb': -19.472851824831352}
# [model] *WARNING* Ignored blocks/options: ['sampler', 'output', 'version']
# [classy] `classy` module loaded successfully from /home/theppawan/miniconda3/envs/class_env/lib/python3.10/site-packages/classy
# [bao.desi_2024_bao_all] Initialized.
#
# Running CLASS and likelihoods at mean parameters... (this may take a moment)
#
# ========================================
# Mean Deviance ( D-bar )         : 1422.02
# Deviance at mean ( D(theta_bar) ): 2546.78
# Effective parameters ( p_D )    : -1124.76
# DIC                             : 297.25
# ========================================
# (np.float64(297.2547057143465), np.float64(-1124.7634620579047))

# %%
compute_dic(str(chain_dir / 'lcdm/DESI+CMB+SNIa/lcdm_DESI+CMB+SNIa'), burnin_fraction=0.3)
# Out:
# Loading chains for prefix: /home/theppawan/cosmo-research/quintom-project/chains/lcdm/DESI+CMB+SNIa/lcdm_DESI+CMB+SNIa
# Loading Cobaya model from: /home/theppawan/cosmo-research/quintom-project/chains/lcdm/DESI+CMB+SNIa/lcdm_DESI+CMB+SNIa.updated.yaml
# Dynamically summing the following chi2 columns: ['chi2__bao.desi_2024_bao_all', 'chi2__cmb_distance_prior.CMB_Distance_Prior_wcdm', 'chi2__sn.pantheonplus']
# Evaluated Mean Parameters: {'H0': 67.95566394544218, 'omega_b': 0.022533682190074216, 'omega_cdm': 0.119164594756671}
# [model] *WARNING* Ignored blocks/options: ['sampler', 'output', 'version']
# [classy] `classy` module loaded successfully from /home/theppawan/miniconda3/envs/class_env/lib/python3.10/site-packages/classy
# [bao.desi_2024_bao_all] Initialized.
#
# Running CLASS and likelihoods at mean parameters... (this may take a moment)
#
# ========================================
# Mean Deviance ( D-bar )         : 1426.49
# Deviance at mean ( D(theta_bar) ): 1423.54
# Effective parameters ( p_D )    : 2.95
# DIC                             : 1429.44
# ========================================
# (np.float64(1429.4437696180782), np.float64(2.95201909227103))
